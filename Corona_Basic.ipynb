# %%
def corona_risk():
    print("Lütfen Tc kimlik no ve şifrenizi giriniz...")
    print("Şifreniz 6 karakter olmalıdır. İlk iki karakteri harf olarak girin. İlk harfi büyük, 2. harfi küçük girmeyi unutmayın!!")
    numbers=[]
    tc_no=input("Lütfen tc kimlik numaranızı giriniz : ")
    for i in range(0,1):
        if not tc_no.isdigit():
            print("Tc numaranızı lütfen rakam olarak giriniz..")
            break
        elif tc_no.isdigit():
            if len(tc_no)!=11:
                print("Tc kimlik numaranız 11 haneli olmalıdır..")
                break
            elif len(tc_no)==11:
                if tc_no[0]=="0":
                    print("Tc kimlik numaranız 0 ile başlayamaz")
                    break
                elif tc_no[0]!="0":
                    for i in tc_no:
                        numbers.append(int(i))
                    if not sum(numbers[:10]) % 10 == numbers[10]:
                        print("Tc numaranız hatalı")
                        break
                    elif sum(numbers[:10]) % 10 == numbers[10]:
                        a= 7*sum(numbers[0:10:2])
                        b= sum(numbers[1:9:2])
                        if (a-b)%10!=numbers[9]:
                            print("Tc kimlik numarası sistemde kayıtlı değil")
                            break
                        elif (a-b)%10==numbers[9]:
                            print("Tc kimlik numaranız onaylandı. Lütfen şifrenizi belirleyin!!")
                            password=input("Şifrenizi onaylamak için giriniz = ")
                            if password[0:2].isdigit():
                                print("ilk 2 değer rakam girmediniz!!")
                                break
                            elif not password[0:2].isdigit():
                                if not password[2:5].isdigit():
                                    print("Son 4 hane rakam olmalı")
                                    break
                                elif password[2:5].isdigit():
                                    if password[0]!=password[0].upper():
                                        print("İlk harf büyük girilmeli")
                                        break
                                    elif password[0]==password[0].upper():
                                        if password[1]!=password[1].lower():
                                            print("2. harf küçük girilmelidir.")
                                            break
                                        elif password[1]==password[1].lower():
                                            if password[2]==password[3]==password[4]==password[5]:
                                                print("Rakamların hepsi eşit olamaz..")
                                                break
                                            elif password[2]!=password[3]!=password[4]!=password[5]:
                                                if password[3]==password[4]==password[5]:
                                                    print("rakamların son 3 hanesi eşit olamaz")
                                                    break
                                                elif password[3]!=password[4]!=password[5]:
                                                    if password[4]==password[5]:
                                                        print("Rakamların son iki hanesi eşit olamaz..")
                                                        break
                                                    elif password[4]!=password[5]:
                                                        if password[2]=="1" or password[2]=="2":
                                                            print("Şifre 1 veya 2 ile başlayamaz")
                                                        elif password[2]!="1" and password[2]!="2":
                                                            print("Şifre belirleme işleminiz başarı ile gerçekleşti.")
                                                            print("E-Nabız sitesine yönlendiriliyorsunuz...")
                                                            driver=webdriver.Chrome()
                                                            driver.get("https://enabiz.gov.tr/")
                                                            print("Risk analiz sistemine yönlendiriliyorsunuz")
                                                            age=int(input("Lütfen yaşınızı giriniz = "))
                                                            if age<0:
                                                                print("Eksi bir değer girilemez.")
                                                                break
                                                            elif age>0 and age<18:
                                                                print("Risk grubu içerisinde bulunmuyorsunuz.")
                                                                break
                                                            elif age>=18 and age<40:
                                                                print("Risk grubu içerisinde bulunmuyorsunuz.")
                                                                break
                                                            elif age>=40 and age<60:
                                                                sigara_control=input("Sigara kullanıyor musunuz? E/H")
                                                                if sigara_control=="H":
                                                                    print("Aşırı kalabalık ortamlardan uzak durun.")
                                                                    print("Herhangi bir rahatsızlık hissederseniz lütfen ihmal etmeyin")
                                                                    break
                                                                elif sigara_control=="E":
                                                                    cronic=input("Astım rahatsızlığınız var mı? E/H")
                                                                    if cronic=="H":
                                                                        print("Lütfen en kısa zamanda sigarayı bırakın")
                                                                        risk1=random.randint(1,3)
                                                                        print(f"Risk düzeyiniz={risk1}")
                                                                    elif cronic=="E":
                                                                        print("Lütfen en kısa zamanda sigarayı bırakın")
                                                                        risk2=random.randint(3,6)
                                                                        print("Herhangi bir rahatsızlık hissederseniz en yakın şehir hastanesine müraacat edin.")
                                                                        print(f"Risk düzeyiniz={risk2}")
                                                            
                                                            elif age>=60 and age<90:
                                                                print("Çok Riskli bir yaş aralığınız var. aşı sırasında önceliklisiniz.. ")
                                                                print("Risk seviyeniz maximun-yüksek. Lütfen acilen sigarayı bırakın")
                                                                print("Sigara kullandığınız için hayati tehlikeniz var..")
                                                                adress=input("Sağlık ekiplerinin acil müdahalesi için Lütfen ev adresinizi giriniz = ")
                                                                gsm=input("Lütfen gsm bilginizi başında 0 olmadan giriniz= " )
                                                                if len(gsm)!=10:
                                                                    print("Gsm numaranız hatalı...")
                                                                elif len(gsm)==10:
                                                                    if not gsm.isdigit():
                                                                        print("Gsm numaranızı rakam ile giriniz...")
                                                                    elif gsm.isdigit():
                                                                        if gsm[0]!="5" :
                                                                            print("Gsm numarasının ilk hanesi 5 ile başlamak zorundadır.")
                                                                            break
                                                                        elif gsm[0]=="5":
                                                                            print("Ev adresiniz ve gsm numaranız kaydedildi..")
                                                                            print(f"Ev adresiniz={adress}\n gsm numaranız={gsm}")
                                                                            print("Acil Durumlar için Lütfen size gönderceğimiz no ile bizi hemen arayın..")
                                                                            gonder_istek=input("Size acil durumlar için numaramızı göndermemizi ister misiniz? E/H")
                                                                            if gonder_istek=="E":
                                                                                destek_number="555458969"
                                                                                print("Acil durumlar için bize direk ulaşacağınız numara={destek_no} ")
                                                                            elif gonder_istek=="H":
                                                                                print("Acil durumlar için 112 Acil Koddan bize ulaşabilirsiniz..")

# %%
import random
